# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanKatorgin/Python-libraries-for-data-analysis/blob/main/%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B8_Python_%D0%B4%D0%BB%D1%8F_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85_%D0%B4%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Курс "Библиотеки Python для анализа данных". Домашнее задание 3. Продвинутый pandas. Каторгин И.П.

# %% [markdown]
# Задание 1.
#
# Для датафрейма log из материалов занятия создайте столбец source_type по правилам:
#
# если источник traffic_source равен Yandex или Google, то в source_type ставится organic;
#
# для источников paid и email из России ставим ad;
#
# для источников paid и email не из России ставим other;
#
# все остальные варианты берём из traffic_source без изменений.

# %%
import pandas as pd

# %%
log = pd.read_csv('visit_log.csv', sep=';')
log.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source
# 0  b1613cc09f         yandex
# 1  4c3ec14bee         direct
# 2  a8c40697fb         yandex
# 3  521ac1d6a0         yandex
# 4  d7323c571c         yandex

# %%
def source_type(row):
  if (row['traffic_source'] == 'yandex') or (row['traffic_source'] == 'google'):
    return 'organic'
  if (row['traffic_source'] == 'paid' and row['region'] == 'Russia'):
    return 'ad'
  if (row['traffic_source'] == 'paid' and row['region'] != 'Russia'):
    return 'other'
  return row['traffic_source']

# %%
log['source_type'] = log.apply(source_type, axis=1)
log.head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source source_type
# 0  b1613cc09f         yandex     organic
# 1  4c3ec14bee         direct      direct
# 2  a8c40697fb         yandex     organic
# 3  521ac1d6a0         yandex     organic
# 4  d7323c571c         yandex     organic

# %%
log.loc[log.traffic_source == 'paid'].head()
# Out:
#      timestamp    visit_id                                 url   region  \
# 6   1549980742  b0f66adc83  https://host.ru/b8b58337d272ee7b15   Russia
# 12  1549980789  15ec7bf0b5  https://host.ru/8e88d4703848cc0ec4   Russia
# 15  1549980797  5322fecfc9  https://host.ru/4adc8a29b212051b04  Belarus
# 17  1549980807  0a88111852  https://host.ru/2fcb223266880ccf57  Ukraine
# 26  1549980852  659d36ca56  https://host.ru/4adc8a29b212051b04   Russia
#
#        user_id traffic_source source_type
# 6   13fc55e781           paid          ad
# 12  6d1d81f7f8           paid          ad
# 15  9a45d98867           paid       other
# 17  a2ba8fa3db           paid       other
# 26  c4bd1ae3af           paid          ad

# %%
log.loc[log.traffic_source == 'yandex'].head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
# 5  1549980742  8855508aad  https://host.ru/df646c3676cc259fa0  Russia
#
#       user_id traffic_source source_type
# 0  b1613cc09f         yandex     organic
# 2  a8c40697fb         yandex     organic
# 3  521ac1d6a0         yandex     organic
# 4  d7323c571c         yandex     organic
# 5  fc43898e47         yandex     organic

# %%
log.loc[log.traffic_source == 'google'].head()
# Out:
#      timestamp    visit_id                                 url   region  \
# 11  1549980785  71b6c1d538  https://host.ru/c8d9213a31839f9a3a  Ukraine
# 16  1549980801  374708fff7  https://host.ru/39fa884393666d45fc   Russia
# 21  1549980823  c90232586b  https://host.ru/da83c74e35e7806fe0  Ukraine
# 46  1549980969  878f32f76b  https://host.ru/186c4d6b47dbde0e74   Russia
# 51  1549981001  8e8fe47e4a  https://host.ru/39fa884393666d45fc  Ukraine
#
#        user_id traffic_source source_type
# 11  3b13701488         google     organic
# 16  e9bd59e22d         google     organic
# 21  a00405d70c         google     organic
# 46  ee82681887         google     organic
# 51  8aa7273421         google     organic

# %%
log.loc[log.region == 'Russia'].head()
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source source_type
# 0  b1613cc09f         yandex     organic
# 1  4c3ec14bee         direct      direct
# 2  a8c40697fb         yandex     organic
# 3  521ac1d6a0         yandex     organic
# 4  d7323c571c         yandex     organic

# %%
log.loc[log.region != 'Russia'].head()
# Out:
#      timestamp    visit_id                                 url   region  \
# 8   1549980760  af5570f5a1  https://host.ru/3004a8273caeef2867    China
# 10  1549980777  01d448afd9  https://host.ru/a5dda93e70318570c0    India
# 11  1549980785  71b6c1d538  https://host.ru/c8d9213a31839f9a3a  Ukraine
# 13  1549980792  dd46c3eebb  https://host.ru/3004a8273caeef2867    China
# 14  1549980793  e7ecebbc59  https://host.ru/05e41944dd85a900a6  Belarus
#
#        user_id traffic_source source_type
# 8   45664f7af2         direct      direct
# 10  27e76a4a80         direct      direct
# 11  3b13701488         google     organic
# 13  7e301c8c41         direct      direct
# 14  ac52dedc3b         direct      direct

# %% [markdown]
# Задание 2.
#
# В файле URLs.txt содержатся URL страниц новостного сайта. Вам нужно отфильтровать его по адресам страниц с текстами новостей. Известно, что шаблон страницы новостей имеет внутри URL конструкцию: /, затем 8 цифр, затем дефис. Выполните действия:
#
# 1. Прочитайте содержимое файла с датафрейм.
#
# 2. Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствие с заданным шаблоном.

# %%
url = pd.read_csv('URLs.txt')
url
# Out:
#                                                   url
# 0                                             /world/
# 1                                            /latest/
# 2                                       /?updated=top
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# ..                                                ...
# 88  /cis/35984145-kreml-prokommentiroval-soobschen...
# 89  /video/36071019-olimpiyskie-obekty-rio-prevrat...
# 90  /science/36151301-nazvano-posledstvie-zloupotr...
# 91  /incidents/36027330-vospitatelnitsu-zatravili-...
# 92  /world/36103095-dominikanskih-zhurnalistov-ubi...
#
# [93 rows x 1 columns]

# %%
import re

url['len_str'] = url['url'].apply(lambda string: len(string))
url = url.sort_values('len_str', ascending=True)

for string in url.url:
  tamplate = str(re.findall(r'\/\d{8}\-', string))[2:-2]
  url.loc[url.url.str.contains(tamplate), 'news'] = tamplate
  url_news = url.loc[url.news != '']

url_news[['news', 'url']].head()
# Out:
#           news                                               url
# 45  /36151719-            /video/36151719-petrosyanu-grozit-sud/
# 59  /36213214-      /articles/36213214-vozmozhna-bolshaya-voyna/
# 16  /36174817-    /starlife/36174817-guzeeva-rasstalas-s-muzhem/
# 57  /36240935-   /starlife/36240935-dzhigurde-postavili-diagnoz/
# 47  /36193368-  /articles/36193368-donbass-reshil-udarit-pervym/

# %% [markdown]
# Задание 3.
#
# Используйте файл с оценками фильмов ml-latest-small/ratings.csv. Посчитайте среднее время жизни пользователей, которые выставили более 100 оценок. Под временем жизни понимается разница между максимальным и минимальным значениями столбца timestamp для данного значения userId.

# %%
ratings = pd.read_csv('ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
min_max_table = ratings.groupby('userId').agg({'timestamp': ['min', 'max', 'count']})['timestamp'].sort_values('count', ascending = False)
min_max_table.reset_index()
# Out:
#      userId         min         max  count
# 0       547   974777109  1476587644   2391
# 1       564   974708446   976224804   1868
# 2       624  1019123866  1476616373   1735
# 3        15   997937239  1469330735   1700
# 4        73  1255500852  1476086345   1610
# ..      ...         ...         ...    ...
# 666     296  1298158632  1298166310     20
# 667     289  1328935420  1328935859     20
# 668     249   839461218   839463782     20
# 669     221  1111551492  1111551662     20
# 670       1  1260759108  1260759205     20
#
# [671 rows x 4 columns]

# %%
table_ = min_max_table.loc[min_max_table['count'] > 100, ['min', 'max', 'count']].sort_values('count')
table_.head()
# Out:
#                min         max  count
# userId
# 67       854711770   854715906    103
# 257     1338006929  1449941803    103
# 623     1225255417  1225258519    103
# 36       847056510   853005800    104
# 217     1108160000  1108160981    104

# %%
lifetime = table_['max'] - table_['min']
round(lifetime.mean(), 3)
# Out:
# 40080507.45

# %% [markdown]
# Задание 4.
#
# Дана статистика услуг перевозок клиентов компании по типам (см. файл “Python_13_join.ipynb” в разделе «Материалы для лекции “Продвинутый pandas”» ---- Ноутбуки к лекции «Продвинутый pandas»).
#
# Нужно сформировать две таблицы:
#
# 1. таблицу с тремя типами выручки для каждого client_id без указания адреса клиента;
#
# 2. аналогичную таблицу по типам выручки с указанием адреса клиента.
#
# Обратите внимание, что в процессе объединения таблиц данные не должны теряться.

# %% [markdown]
# Дана статистика услуг перевозок клиентов компании по типам:
#
# rzd - железнодорожные перевозки
#
# auto - автомобильные перевозки
#
# air - воздушные перевозки
#
# client_base - адреса клиентов

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1',
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %%
(rzd
 .merge(auto, on = 'client_id', how = 'outer')
 .merge(air, on = 'client_id', how = 'outer')
 .merge(client_base['client_id'], on = 'client_id', how = 'outer'))
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue
# 0        111       1093.0           NaN          NaN
# 1        112       2810.0           NaN          NaN
# 2        113      10283.0       57483.0          NaN
# 3        114       5774.0          83.0          NaN
# 4        115        981.0         912.0         81.0
# 5        116          NaN        4834.0          4.0
# 6        117          NaN          98.0         13.0
# 7        118          NaN           NaN        173.0

# %%
(client_base
 .merge(rzd, on = 'client_id', how = 'left')
 .merge(auto, on = 'client_id', how = 'left')
 .merge(air, on = 'client_id', how = 'left'))
# Out:
#    client_id          address  rzd_revenue  auto_revenue  air_revenue
# 0        111  Комсомольская 4       1093.0           NaN          NaN
# 1        112   Энтузиастов 8а       2810.0           NaN          NaN
# 2        113  Левобережная 1а      10283.0       57483.0          NaN
# 3        114          Мира 14       5774.0          83.0          NaN
# 4        115        ЗЖБИиДК 1        981.0         912.0         81.0
# 5        116    Строителей 18          NaN        4834.0          4.0
# 6        117  Панфиловская 33          NaN          98.0         13.0
# 7        118     Мастеркова 4          NaN           NaN        173.0
